# %% [markdown]
# # FnGuide Crawling

# %%
#!/usr/bin/env python3
"""
리팩토링된 동적 테이블 크롤러
- 함수 분리로 가독성 향상
- 클래스 기반 구조화
- 에러 처리 개선
- 디버그 모드 분리
"""

import requests
import pandas as pd
from bs4 import BeautifulSoup, Tag
from typing import Dict, List, Tuple, Optional
import logging

# 로깅 설정
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# 파티션 폴더명 접두사 (GCS 저장 경로용)
QUARTER_PREFIX = "quarter="

# 정적 HTML에서 가져올 테이블 (원본 utils/fnguide.py)
STATIC_TABLE_MAP = [
    ("market_conditions", 0),
    ("earning_issue", 1),
    ("holdings_status", 2),
    ("governance", 3),
    ("shareholders", 4),
    ("bond_rating", 6),
    ("analysis", 7),
    ("industry_comparison", 8),
    ("financialhighlight_annual", 11),
    ("financialhighlight_netquarter", 12),
]

DYNAMIC_TABLE_TITLES = ["포괄손익계산서", "재무상태표", "현금흐름표"]

# %%
static_url = "https://comp.fnguide.com/SVO2/ASP/SVD_main.asp?pGB=1&gicode=A{stock}"
dynamic_url = "https://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&gicode=A{stock}&cID=&MenuYn=Y&ReportGB=&NewMenuID=103&stkGb=701"

# %% [markdown]
# ## 재무제표 정보

# %%
# =============================================================================
# 헬퍼 클래스들
# =============================================================================

class TableFinder:
    """테이블 찾기 전담 클래스"""
    
    @staticmethod
    def find_by_title(soup: BeautifulSoup, title: str) -> Optional[Tag]:
        """제목으로 테이블 찾기"""
        for table in soup.find_all("table"):
            if title in table.get_text():
                logger.info(f"'{title}' 테이블 발견")
                return table
        
        logger.warning(f"'{title}' 테이블을 찾을 수 없음")
        return None


class HeaderExtractor:
    """테이블 헤더 추출 전담 클래스"""
    
    @staticmethod
    def extract_index_list(thead: Tag) -> List[str]:
        """
        thead에서 인덱스 리스트 추출
        
        Args:
            thead: thead 태그
        
        Returns:
            인덱스 리스트 (날짜/기간 데이터)
        """
        thead_rows = thead.find_all("tr")
        index_rows: List[List[str]] = []
        
        for tr in thead_rows:
            row_headers = HeaderExtractor._extract_row_headers(tr)
            if row_headers:
                index_rows.append(row_headers)
        
        # 가장 긴 행을 선택 (가장 상세한 헤더)
        index_list = max(index_rows, key=len) if index_rows else []
        
        total_headers = sum(len(tr.find_all("th")) for tr in thead_rows)
        logger.info(f"기간 데이터 (헤더 {total_headers}개 중 {len(index_list)}개): {index_list}")
        
        return index_list
    
    @staticmethod
    def _extract_row_headers(tr: Tag) -> List[str]:
        """
        단일 행에서 헤더 추출 (colspan 처리)
        
        Args:
            tr: tr 태그
        
        Returns:
            헤더 리스트
        """
        row_headers = []
        ths = tr.find_all("th", recursive=False)
        
        for col_idx, th in enumerate(ths):
            text = th.get_text(strip=True)
            if not text:
                continue
            
            # 첫 번째 th는 행 구분자로 스킵 (2개 이상일 때만)
            if col_idx == 0 and len(ths) > 1:
                continue
            
            # colspan 처리
            colspan = HeaderExtractor._get_colspan(th)
            row_headers.extend([text] * colspan)
        
        return row_headers
    
    @staticmethod
    def _get_colspan(th: Tag) -> int:
        """colspan 속성 추출"""
        colspan_attr = th.get("colspan")
        try:
            return int(colspan_attr) if colspan_attr else 1
        except ValueError:
            return 1


class BodyExtractor:
    """테이블 바디 추출 전담 클래스"""
    
    def __init__(self, debug: bool = False):
        self.debug = debug
        self.last_span_text: Optional[str] = None
    
    def extract(
        self,
        tbody: Tag,
        index_list: List[str]
    ) -> Dict[Tuple[str, str], List[str]]:
        """
        tbody에서 데이터 딕셔너리 추출
        
        Args:
            tbody: tbody 태그
            index_list: 헤더 인덱스 리스트
        
        Returns:
            {(카테고리, 항목): [값들]} 형태의 딕셔너리
        """
        data_dict = {}
        tbody_trs = tbody.find_all("tr", recursive=False)
        
        logger.info(f"발견된 행 수: {len(tbody_trs)}")
        
        if self.debug and tbody_trs:
            logger.debug(f"첫 행 HTML: {str(tbody_trs[0])[:500]}")
        
        processed_count = 0
        
        for idx, tr in enumerate(tbody_trs):
            self._log_progress(idx, len(tbody_trs))
            
            try:
                # 행 데이터 추출
                column_tuple, values = self._extract_row_data(tr, idx)
                
                if not column_tuple or not values:
                    continue
                
                # 헤더와 값 개수 검증
                if len(values) == len(index_list):
                    data_dict[column_tuple] = values
                    processed_count += 1
                    
                    if self.debug and idx < 3:
                        logger.debug(f"행 {idx} 성공!")
                else:
                    if self.debug and idx < 5:
                        logger.warning(
                            f"행 {idx} 길이 불일치: "
                            f"헤더={len(index_list)}, 값={len(values)} (스킵)"
                        )
            
            except Exception as e:
                if self.debug and idx < 5:
                    logger.error(f"행 {idx} 처리 중 에러: {e}")
                continue
        
        logger.info(f"처리 완료: {processed_count}/{len(tbody_trs)} 행")
        
        return data_dict
    
    def _extract_row_data(
        self,
        tr: Tag,
        idx: int
    ) -> Tuple[Optional[Tuple[str, str]], List[str]]:
        """
        단일 행에서 컬럼명과 값 추출
        
        Args:
            tr: tr 태그
            idx: 행 인덱스
        
        Returns:
            (컬럼명_튜플, 값_리스트)
        """
        # th 찾기
        th = tr.find("th")
        if not th:
            if self.debug and idx < 3:
                logger.debug(f"행 {idx}: th 없음")
            return None, []
        
        # 컬럼명 추출
        column_tuple = self._extract_column_name(th, idx)
        
        # td 값들 추출
        tds = tr.find_all("td", recursive=False)
        values = [td.get_text(strip=True) for td in tds]
        
        if self.debug and idx < 3:
            logger.debug(
                f"행 {idx}: column={column_tuple}, "
                f"td 개수={len(tds)}, 값={values[:3] if values else '없음'}"
            )
        
        return column_tuple, values
    
    def _extract_column_name(self, th: Tag, idx: int) -> Tuple[str, str]:
        """
        th에서 컬럼명 튜플 추출 (span 고려)
        
        Args:
            th: th 태그
            idx: 행 인덱스
        
        Returns:
            (카테고리, 항목) 튜플
        """
        span = th.find("span")
        th_text = th.get_text(strip=True)
        
        # span이 있는 경우: 새로운 상위 카테고리
        if span:
            span_text = span.get_text(strip=True)
            self.last_span_text = span_text
            column_tuple = (span_text, th_text)
            
            if self.debug and idx < 3:
                logger.debug(f"행 {idx} (span): {column_tuple}")
        
        # span 없는 경우: 이전 카테고리 사용
        else:
            if self.last_span_text:
                column_tuple = (self.last_span_text, th_text)
            else:
                column_tuple = (th_text, "")
            
            if self.debug and idx < 3:
                logger.debug(f"행 {idx} (no span): {column_tuple}")
        
        return column_tuple
    
    @staticmethod
    def _log_progress(idx: int, total: int):
        """진행상황 로깅 (20개마다)"""
        if idx > 0 and idx % 20 == 0:
            logger.info(f"처리 중: {idx}/{total} 행")

# %%
# =============================================================================
# 메인 파서 클래스
# =============================================================================

class FinancialTableParser:
    """재무제표 테이블 파서"""
    
    def __init__(self, debug: bool = False):
        """
        Args:
            debug: 디버그 모드
        """
        self.debug = debug
        self.table_finder = TableFinder()
        self.header_extractor = HeaderExtractor()
    
    def parse_table(
        self,
        soup: BeautifulSoup,
        title: str
    ) -> Optional[pd.DataFrame]:
        """
        단일 테이블 파싱
        
        Args:
            soup: BeautifulSoup 객체
            title: 테이블 제목
        
        Returns:
            DataFrame 또는 None
        """
        logger.info(f"\n{title} 데이터 수집 중...")
        
        # 1. 테이블 찾기
        table = self.table_finder.find_by_title(soup, title)
        if not table:
            return None
        
        # 2. thead 추출
        thead = table.find("thead")
        if not thead:
            logger.warning("thead를 찾을 수 없음")
            return None
        
        # 3. 헤더 인덱스 추출
        index_list = self.header_extractor.extract_index_list(thead)
        if not index_list:
            logger.warning("인덱스 리스트가 비어있음")
            return None
        
        # 4. tbody 추출
        tbody = table.find("tbody")
        if not tbody:
            logger.warning("tbody를 찾을 수 없음")
            return None
        
        # 5. 데이터 딕셔너리 추출
        body_extractor = BodyExtractor(debug=self.debug)
        data_dict = body_extractor.extract(tbody, index_list)
        
        if not data_dict:
            logger.warning("데이터가 비어있음")
            return None
        
        # 6. DataFrame 생성
        df = self._create_dataframe(data_dict, index_list)
        
        logger.info(f"완료! DataFrame shape: {df.shape}")
        
        return df
    
    @staticmethod
    def _create_dataframe(
        data_dict: Dict[Tuple[str, str], List[str]],
        index_list: List[str]
    ) -> pd.DataFrame:
        """
        데이터 딕셔너리에서 DataFrame 생성
        
        Args:
            data_dict: {(카테고리, 항목): [값들]} 딕셔너리
            index_list: 인덱스 리스트
        
        Returns:
            멀티인덱스 컬럼을 가진 DataFrame
        """
        df = pd.DataFrame(data_dict, index=index_list)
        
        # 멀티인덱스로 컬럼 변환
        df.columns = pd.MultiIndex.from_tuples(df.columns)
        
        return df

# %%
# =============================================================================
# 메인 함수 (리팩토링 버전)
# =============================================================================

def get_dynamic_tables(
    stock: str,
    dynamic_url: str,
    table_titles: List[str],
    debug: bool = False
) -> Dict[str, List[Dict]]:
    """
    동적 테이블 수집
    
    Args:
        stock: 종목 코드
        dynamic_url: URL 템플릿 ('{stock}' 포함)
        table_titles: 수집할 테이블 제목 리스트
        debug: 디버그 모드
    
    Returns:
        {테이블명: 레코드_리스트} 딕셔너리
    """
    result_dict = {}
    
    # 1. 페이지 가져오기
    url = dynamic_url.format(stock=stock)
    logger.info(f"Dynamic URL: {url}")
    
    try:
        response = requests.get(url, timeout=30)
        response.raise_for_status()
    except requests.RequestException as e:
        logger.error(f"페이지 요청 실패: {e}")
        return {title: [] for title in table_titles}
    
    # 2. BeautifulSoup 파싱
    soup = BeautifulSoup(response.text, "html.parser")
    
    # 3. 파서 생성
    parser = FinancialTableParser(debug=debug)
    
    # 4. 각 테이블 파싱
    for title in table_titles:
        try:
            df = parser.parse_table(soup, title)
            
            if df is not None:
                # DataFrame을 레코드로 변환
                result_dict[title] = dataframe_to_records(df)
            else:
                result_dict[title] = []
        
        except Exception as e:
            logger.error(f"{title} 수집 실패: {e}")
            result_dict[title] = []
    
    return result_dict


def dataframe_to_records(df: pd.DataFrame) -> List[Dict]:
    """
    DataFrame을 레코드 리스트로 변환
    
    Args:
        df: 변환할 DataFrame
    
    Returns:
        레코드 딕셔너리 리스트
    """
    return df.to_dict('records')

# %%
# 실행
result = get_dynamic_tables(
    stock="005930",
    dynamic_url=dynamic_url,
    table_titles=DYNAMIC_TABLE_TITLES,
    debug=True  # 디버그 모드
)
# Out:
# INFO:__main__:Dynamic URL: https://comp.fnguide.com/SVO2/ASP/SVD_Finance.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=&NewMenuID=103&stkGb=701
# INFO:__main__:
# 포괄손익계산서 데이터 수집 중...
# INFO:__main__:'포괄손익계산서' 테이블 발견
# INFO:__main__:기간 데이터 (헤더 7개 중 6개): ['2022/12', '2023/12', '2024/12', '2025/09', '전년동기', '전년동기(%)']
# INFO:__main__:발견된 행 수: 79
# INFO:__main__:처리 중: 20/79 행
# INFO:__main__:처리 중: 40/79 행
# INFO:__main__:처리 중: 60/79 행
# INFO:__main__:처리 완료: 79/79 행
# INFO:__main__:완료! DataFrame shape: (6, 79)
# INFO:__main__:
# 재무상태표 데이터 수집 중...
# INFO:__main__:'재무상태표' 테이블 발견
# INFO:__main__:기간 데이터 (헤더 5개 중 4개): ['2022/12', '2023/12', '2024/12', '2025/09']
# INFO:__main__:발견된 행 수: 66
# INFO:__main__:처리 중: 20/66 행
# INFO:__main__:처리 중: 40/66 행
# INFO:__main__:처리 중: 60/66 행
# INFO:__main__:처리 완료: 66/66 행
# INFO:__main__:완료! DataFrame shape: (4, 66)
# INFO:__main__:
# 현금흐름표 데이터 수집 중...
# INFO:__main__:'현금흐름표' 테이블 발견
# INFO:__main__:기간 데이터 (헤더 5개 중 4개): ['2022/12', '2023/12', '2024/12', '2025/09']
# INFO:__main__:발견된 행 수: 158
# INFO:__main__:처리 중: 20/158 행
# INFO:__main__:처리 중: 40/158 행
# INFO:__main__:처리 중: 60/158 행
# INFO:__main__:처리 중: 80/158 행
# INFO:__main__:처리 중: 100/158 행
# INFO:__main__:처리 중: 120/158 행
# INFO:__main__:처리 중: 140/158 행
# INFO:__main__:처리 완료: 158/158 행
# INFO:__main__:완료! DataFrame shape: (4, 158)

# %%
result
# Out:
# {'포괄손익계산서': [{('매출액', ''): '3,022,314',
#    ('매출원가', ''): '1,900,418',
#    ('매출총이익', ''): '1,121,896',
#    ('판매비와관리비', '판매비와관리비계산에 참여한 계정 펼치기'): '688,130',
#    ('판매비와관리비', '인건비'): '80,937',
#    ('판매비와관리비', '유무형자산상각비'): '22,391',
#    ('판매비와관리비', '연구개발비'): '249,192',
#    ('판매비와관리비', '광고선전비'): '61,130',
#    ('판매비와관리비', '판매비'): '139,969',
#    ('판매비와관리비', '관리비'): '74,579',
#    ('판매비와관리비', '기타원가성비용'): '',
#    ('판매비와관리비', '기타'): '59,932',
#    ('판매비와관리비', '영업이익'): '433,766',
#    ('판매비와관리비', '영업이익(발표기준)'): '433,766',
#    ('금융수익', '금융수익계산에 참여한 계정 펼치기'): '208,290',
#    ('금융수익', '이자수익'): '27,205',
#    ('금융수익', '배당금수익'): '',
#    ('금융수익', '외환이익'): '165,379',
#    ('금융수익', '대손충당금환입액'): '',
#    ('금융수익', '매출채권처분이익'): '',
#    ('금융수익', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('금융수익', '금융자산처분이익'): '',
#    ('금융수익', '금융자산평가이익'): '',
#    ('금융수익', '금융자산손상차손환입'): '',
#    ('금융수익', '파생상품이익'): '15,707',
#    ('금융수익', '기타금융수익'): '',
#    ('금융원가', '금융원가계산에 참여한 계정 펼치기'): '190,277',
#    ('금융원가', '이자비용'): '7,630',
#    ('금융원가', '외환손실'): '168,097',
#    ('금융원가', '대손상각비'): '',
#    ('금융원가', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('금융원가', '매출채권처분손실'): '',
#    ('금융원가', '금융자산처분손실'): '',
#    ('금융원가', '금융자산평가손실'): '',
#    ('금융원가', '금융자산손상차손'): '',
#    ('금융원가', '파생상품손실'): '14,550',
#    ('금융원가', '기타금융원가'): '',
#    ('기타수익', '기타수익계산에 참여한 계정 펼치기'): '19,621',
#    ('기타수익', '이자수익'): '',
#    ('기타수익', '배당금수익'): '4,146',
#    ('기타수익', '외환이익'): '',
#    ('기타수익', '재고자산감모손실환입'): '',
#    ('기타수익', '재고자산폐기(처분)이익'): '',
#    ('기타수익', '당기손익-공정가치측정\xa0금융자산평가이익'): '',
#    ('기타수익', '자산처분(폐기)이익'): '1,591',
#    ('기타수익', '자산평가이익'): '',
#    ('기타수익', '자산손상차손환입'): '',
#    ('기타수익', '파생상품이익'): '',
#    ('기타수익', '임대료수익'): '1,409',
#    ('기타수익', '로열티수익'): '',
#    ('기타수익', '수수료수익'): '',
#    ('기타수익', '대손충당금환입'): '',
#    ('기타수익', '충당부채환입액'): '',
#    ('기타수익', '기타'): '12,474',
#    ('기타비용', '기타비용계산에 참여한 계정 펼치기'): '17,902',
#    ('기타비용', '이자비용'): '',
#    ('기타비용', '외환손실'): '',
#    ('기타비용', '재고자산감모손실'): '',
#    ('기타비용', '재고자산폐기(처분)손실'): '',
#    ('기타비용', '당기손익-공정가치측정\xa0금융자산평가손실'): '',
#    ('기타비용', '자산처분(폐기)손실'): '613',
#    ('기타비용', '자산평가손실'): '',
#    ('기타비용', '자산손상차손'): '',
#    ('기타비용', '파생상품손실'): '',
#    ('기타비용', '기타대손상각비'): '',
#    ('기타비용', '충당부채전입액'): '',
#    ('기타비용', '기타'): '17,289',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기'): '10,906',
#    ('종속기업,공동지배기업및관계기업관련손익', '지분법손익'): '10,906',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식처분손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식손상관련손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '기타'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '세전계속사업이익'): '464,405',
#    ('종속기업,공동지배기업및관계기업관련손익', '법인세비용'): '-92,136',
#    ('종속기업,공동지배기업및관계기업관련손익', '계속영업이익'): '556,541',
#    ('종속기업,공동지배기업및관계기업관련손익', '중단영업이익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '당기순이익'): '556,541',
#    ('종속기업,공동지배기업및관계기업관련손익', '지배주주순이익'): '547,300',
#    ('종속기업,공동지배기업및관계기업관련손익', '비지배주주순이익'): '9,241'},
#   {('매출액', ''): '2,589,355',
#    ('매출원가', ''): '1,803,886',
#    ('매출총이익', ''): '785,469',
#    ('판매비와관리비', '판매비와관리비계산에 참여한 계정 펼치기'): '719,799',
#    ('판매비와관리비', '인건비'): '86,239',
#    ('판매비와관리비', '유무형자산상각비'): '23,381',
#    ('판매비와관리비', '연구개발비'): '283,397',
#    ('판매비와관리비', '광고선전비'): '52,139',
#    ('판매비와관리비', '판매비'): '125,848',
#    ('판매비와관리비', '관리비'): '87,534',
#    ('판매비와관리비', '기타원가성비용'): '',
#    ('판매비와관리비', '기타'): '61,260',
#    ('판매비와관리비', '영업이익'): '65,670',
#    ('판매비와관리비', '영업이익(발표기준)'): '65,670',
#    ('금융수익', '금융수익계산에 참여한 계정 펼치기'): '161,001',
#    ('금융수익', '이자수익'): '43,580',
#    ('금융수익', '배당금수익'): '',
#    ('금융수익', '외환이익'): '106,087',
#    ('금융수익', '대손충당금환입액'): '',
#    ('금융수익', '매출채권처분이익'): '',
#    ('금융수익', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('금융수익', '금융자산처분이익'): '',
#    ('금융수익', '금융자산평가이익'): '',
#    ('금융수익', '금융자산손상차손환입'): '',
#    ('금융수익', '파생상품이익'): '11,335',
#    ('금융수익', '기타금융수익'): '',
#    ('금융원가', '금융원가계산에 참여한 계정 펼치기'): '126,455',
#    ('금융원가', '이자비용'): '9,303',
#    ('금융원가', '외환손실'): '107,111',
#    ('금융원가', '대손상각비'): '',
#    ('금융원가', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('금융원가', '매출채권처분손실'): '',
#    ('금융원가', '금융자산처분손실'): '',
#    ('금융원가', '금융자산평가손실'): '',
#    ('금융원가', '금융자산손상차손'): '',
#    ('금융원가', '파생상품손실'): '10,042',
#    ('금융원가', '기타금융원가'): '',
#    ('기타수익', '기타수익계산에 참여한 계정 펼치기'): '11,804',
#    ('기타수익', '이자수익'): '',
#    ('기타수익', '배당금수익'): '1,642',
#    ('기타수익', '외환이익'): '',
#    ('기타수익', '재고자산감모손실환입'): '',
#    ('기타수익', '재고자산폐기(처분)이익'): '',
#    ('기타수익', '당기손익-공정가치측정\xa0금융자산평가이익'): '',
#    ('기타수익', '자산처분(폐기)이익'): '1,047',
#    ('기타수익', '자산평가이익'): '',
#    ('기타수익', '자산손상차손환입'): '',
#    ('기타수익', '파생상품이익'): '',
#    ('기타수익', '임대료수익'): '1,503',
#    ('기타수익', '로열티수익'): '',
#    ('기타수익', '수수료수익'): '',
#    ('기타수익', '대손충당금환입'): '',
#    ('기타수익', '충당부채환입액'): '',
#    ('기타수익', '기타'): '7,613',
#    ('기타비용', '기타비용계산에 참여한 계정 펼치기'): '10,833',
#    ('기타비용', '이자비용'): '',
#    ('기타비용', '외환손실'): '',
#    ('기타비용', '재고자산감모손실'): '',
#    ('기타비용', '재고자산폐기(처분)손실'): '',
#    ('기타비용', '당기손익-공정가치측정\xa0금융자산평가손실'): '',
#    ('기타비용', '자산처분(폐기)손실'): '858',
#    ('기타비용', '자산평가손실'): '',
#    ('기타비용', '자산손상차손'): '',
#    ('기타비용', '파생상품손실'): '',
#    ('기타비용', '기타대손상각비'): '',
#    ('기타비용', '충당부채전입액'): '',
#    ('기타비용', '기타'): '9,975',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기'): '8,876',
#    ('종속기업,공동지배기업및관계기업관련손익', '지분법손익'): '8,876',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식처분손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식손상관련손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '기타'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '세전계속사업이익'): '110,063',
#    ('종속기업,공동지배기업및관계기업관련손익', '법인세비용'): '-44,808',
#    ('종속기업,공동지배기업및관계기업관련손익', '계속영업이익'): '154,871',
#    ('종속기업,공동지배기업및관계기업관련손익', '중단영업이익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '당기순이익'): '154,871',
#    ('종속기업,공동지배기업및관계기업관련손익', '지배주주순이익'): '144,734',
#    ('종속기업,공동지배기업및관계기업관련손익', '비지배주주순이익'): '10,137'},
#   {('매출액', ''): '3,008,709',
#    ('매출원가', ''): '1,865,623',
#    ('매출총이익', ''): '1,143,086',
#    ('판매비와관리비', '판매비와관리비계산에 참여한 계정 펼치기'): '815,827',
#    ('판매비와관리비', '인건비'): '91,006',
#    ('판매비와관리비', '유무형자산상각비'): '24,057',
#    ('판매비와관리비', '연구개발비'): '349,981',
#    ('판매비와관리비', '광고선전비'): '54,286',
#    ('판매비와관리비', '판매비'): '141,045',
#    ('판매비와관리비', '관리비'): '88,077',
#    ('판매비와관리비', '기타원가성비용'): '',
#    ('판매비와관리비', '기타'): '67,374',
#    ('판매비와관리비', '영업이익'): '327,260',
#    ('판매비와관리비', '영업이익(발표기준)'): '327,260',
#    ('금융수익', '금융수익계산에 참여한 계정 펼치기'): '167,033',
#    ('금융수익', '이자수익'): '48,191',
#    ('금융수익', '배당금수익'): '',
#    ('금융수익', '외환이익'): '109,976',
#    ('금융수익', '대손충당금환입액'): '',
#    ('금융수익', '매출채권처분이익'): '',
#    ('금융수익', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('금융수익', '금융자산처분이익'): '',
#    ('금융수익', '금융자산평가이익'): '',
#    ('금융수익', '금융자산손상차손환입'): '',
#    ('금융수익', '파생상품이익'): '8,866',
#    ('금융수익', '기타금융수익'): '',
#    ('금융원가', '금융원가계산에 참여한 계정 펼치기'): '129,857',
#    ('금융원가', '이자비용'): '9,039',
#    ('금융원가', '외환손실'): '113,606',
#    ('금융원가', '대손상각비'): '',
#    ('금융원가', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('금융원가', '매출채권처분손실'): '',
#    ('금융원가', '금융자산처분손실'): '',
#    ('금융원가', '금융자산평가손실'): '',
#    ('금융원가', '금융자산손상차손'): '',
#    ('금융원가', '파생상품손실'): '7,211',
#    ('금융원가', '기타금융원가'): '',
#    ('기타수익', '기타수익계산에 참여한 계정 펼치기'): '19,603',
#    ('기타수익', '이자수익'): '',
#    ('기타수익', '배당금수익'): '1,350',
#    ('기타수익', '외환이익'): '',
#    ('기타수익', '재고자산감모손실환입'): '',
#    ('기타수익', '재고자산폐기(처분)이익'): '',
#    ('기타수익', '당기손익-공정가치측정\xa0금융자산평가이익'): '',
#    ('기타수익', '자산처분(폐기)이익'): '816',
#    ('기타수익', '자산평가이익'): '',
#    ('기타수익', '자산손상차손환입'): '',
#    ('기타수익', '파생상품이익'): '',
#    ('기타수익', '임대료수익'): '1,559',
#    ('기타수익', '로열티수익'): '',
#    ('기타수익', '수수료수익'): '',
#    ('기타수익', '대손충당금환입'): '',
#    ('기타수익', '충당부채환입액'): '',
#    ('기타수익', '기타'): '15,878',
#    ('기타비용', '기타비용계산에 참여한 계정 펼치기'): '16,252',
#    ('기타비용', '이자비용'): '',
#    ('기타비용', '외환손실'): '',
#    ('기타비용', '재고자산감모손실'): '',
#    ('기타비용', '재고자산폐기(처분)손실'): '',
#    ('기타비용', '당기손익-공정가치측정\xa0금융자산평가손실'): '',
#    ('기타비용', '자산처분(폐기)손실'): '1,240',
#    ('기타비용', '자산평가손실'): '',
#    ('기타비용', '자산손상차손'): '',
#    ('기타비용', '파생상품손실'): '',
#    ('기타비용', '기타대손상각비'): '',
#    ('기타비용', '충당부채전입액'): '',
#    ('기타비용', '기타'): '15,012',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기'): '7,510',
#    ('종속기업,공동지배기업및관계기업관련손익', '지분법손익'): '7,510',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식처분손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식손상관련손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '기타'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '세전계속사업이익'): '375,297',
#    ('종속기업,공동지배기업및관계기업관련손익', '법인세비용'): '30,784',
#    ('종속기업,공동지배기업및관계기업관련손익', '계속영업이익'): '344,514',
#    ('종속기업,공동지배기업및관계기업관련손익', '중단영업이익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '당기순이익'): '344,514',
#    ('종속기업,공동지배기업및관계기업관련손익', '지배주주순이익'): '336,214',
#    ('종속기업,공동지배기업및관계기업관련손익', '비지배주주순이익'): '8,300'},
#   {('매출액', ''): '2,397,686',
#    ('매출원가', ''): '1,526,491',
#    ('매출총이익', ''): '871,195',
#    ('판매비와관리비', '판매비와관리비계산에 참여한 계정 펼치기'): '635,921',
#    ('판매비와관리비', '인건비'): '69,001',
#    ('판매비와관리비', '유무형자산상각비'): '18,771',
#    ('판매비와관리비', '연구개발비'): '268,761',
#    ('판매비와관리비', '광고선전비'): '44,277',
#    ('판매비와관리비', '판매비'): '107,018',
#    ('판매비와관리비', '관리비'): '75,512',
#    ('판매비와관리비', '기타원가성비용'): '',
#    ('판매비와관리비', '기타'): '52,581',
#    ('판매비와관리비', '영업이익'): '235,274',
#    ('판매비와관리비', '영업이익(발표기준)'): '235,274',
#    ('금융수익', '금융수익계산에 참여한 계정 펼치기'): '112,207',
#    ('금융수익', '이자수익'): '34,628',
#    ('금융수익', '배당금수익'): '',
#    ('금융수익', '외환이익'): '65,352',
#    ('금융수익', '대손충당금환입액'): '',
#    ('금융수익', '매출채권처분이익'): '',
#    ('금융수익', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('금융수익', '금융자산처분이익'): '',
#    ('금융수익', '금융자산평가이익'): '',
#    ('금융수익', '금융자산손상차손환입'): '',
#    ('금융수익', '파생상품이익'): '12,227',
#    ('금융수익', '기타금융수익'): '',
#    ('금융원가', '금융원가계산에 참여한 계정 펼치기'): '76,422',
#    ('금융원가', '이자비용'): '4,405',
#    ('금융원가', '외환손실'): '64,467',
#    ('금융원가', '대손상각비'): '',
#    ('금융원가', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('금융원가', '매출채권처분손실'): '',
#    ('금융원가', '금융자산처분손실'): '',
#    ('금융원가', '금융자산평가손실'): '',
#    ('금융원가', '금융자산손상차손'): '',
#    ('금융원가', '파생상품손실'): '7,550',
#    ('금융원가', '기타금융원가'): '',
#    ('기타수익', '기타수익계산에 참여한 계정 펼치기'): '16,525',
#    ('기타수익', '이자수익'): '',
#    ('기타수익', '배당금수익'): '936',
#    ('기타수익', '외환이익'): '',
#    ('기타수익', '재고자산감모손실환입'): '',
#    ('기타수익', '재고자산폐기(처분)이익'): '',
#    ('기타수익', '당기손익-공정가치측정\xa0금융자산평가이익'): '',
#    ('기타수익', '자산처분(폐기)이익'): '854',
#    ('기타수익', '자산평가이익'): '',
#    ('기타수익', '자산손상차손환입'): '',
#    ('기타수익', '파생상품이익'): '',
#    ('기타수익', '임대료수익'): '1,135',
#    ('기타수익', '로열티수익'): '',
#    ('기타수익', '수수료수익'): '',
#    ('기타수익', '대손충당금환입'): '',
#    ('기타수익', '충당부채환입액'): '',
#    ('기타수익', '기타'): '13,600',
#    ('기타비용', '기타비용계산에 참여한 계정 펼치기'): '8,635',
#    ('기타비용', '이자비용'): '',
#    ('기타비용', '외환손실'): '',
#    ('기타비용', '재고자산감모손실'): '',
#    ('기타비용', '재고자산폐기(처분)손실'): '',
#    ('기타비용', '당기손익-공정가치측정\xa0금융자산평가손실'): '',
#    ('기타비용', '자산처분(폐기)손실'): '392',
#    ('기타비용', '자산평가손실'): '',
#    ('기타비용', '자산손상차손'): '',
#    ('기타비용', '파생상품손실'): '',
#    ('기타비용', '기타대손상각비'): '',
#    ('기타비용', '충당부채전입액'): '',
#    ('기타비용', '기타'): '8,243',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기'): '5,584',
#    ('종속기업,공동지배기업및관계기업관련손익', '지분법손익'): '5,584',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식처분손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식손상관련손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '기타'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '세전계속사업이익'): '284,533',
#    ('종속기업,공동지배기업및관계기업관련손익', '법인세비용'): '28,882',
#    ('종속기업,공동지배기업및관계기업관련손익', '계속영업이익'): '255,651',
#    ('종속기업,공동지배기업및관계기업관련손익', '중단영업이익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '당기순이익'): '255,651',
#    ('종속기업,공동지배기업및관계기업관련손익', '지배주주순이익'): '249,689',
#    ('종속기업,공동지배기업및관계기업관련손익', '비지배주주순이익'): '5,962'},
#   {('매출액', ''): '2,250,826',
#    ('매출원가', ''): '1,392,934',
#    ('매출총이익', ''): '857,892',
#    ('판매비와관리비', '판매비와관리비계산에 참여한 계정 펼치기'): '595,559',
#    ('판매비와관리비', '인건비'): '68,353',
#    ('판매비와관리비', '유무형자산상각비'): '17,883',
#    ('판매비와관리비', '연구개발비'): '247,361',
#    ('판매비와관리비', '광고선전비'): '42,033',
#    ('판매비와관리비', '판매비'): '106,131',
#    ('판매비와관리비', '관리비'): '65,477',
#    ('판매비와관리비', '기타원가성비용'): '',
#    ('판매비와관리비', '기타'): '48,320',
#    ('판매비와관리비', '영업이익'): '262,333',
#    ('판매비와관리비', '영업이익(발표기준)'): '262,333',
#    ('금융수익', '금융수익계산에 참여한 계정 펼치기'): '106,888',
#    ('금융수익', '이자수익'): '35,821',
#    ('금융수익', '배당금수익'): '',
#    ('금융수익', '외환이익'): '64,710',
#    ('금융수익', '대손충당금환입액'): '',
#    ('금융수익', '매출채권처분이익'): '',
#    ('금융수익', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('금융수익', '금융자산처분이익'): '',
#    ('금융수익', '금융자산평가이익'): '',
#    ('금융수익', '금융자산손상차손환입'): '',
#    ('금융수익', '파생상품이익'): '6,356',
#    ('금융수익', '기타금융수익'): '',
#    ('금융원가', '금융원가계산에 참여한 계정 펼치기'): '81,930',
#    ('금융원가', '이자비용'): '6,825',
#    ('금융원가', '외환손실'): '68,746',
#    ('금융원가', '대손상각비'): '',
#    ('금융원가', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('금융원가', '매출채권처분손실'): '',
#    ('금융원가', '금융자산처분손실'): '',
#    ('금융원가', '금융자산평가손실'): '',
#    ('금융원가', '금융자산손상차손'): '',
#    ('금융원가', '파생상품손실'): '6,359',
#    ('금융원가', '기타금융원가'): '',
#    ('기타수익', '기타수익계산에 참여한 계정 펼치기'): '14,767',
#    ('기타수익', '이자수익'): '',
#    ('기타수익', '배당금수익'): '1,014',
#    ('기타수익', '외환이익'): '',
#    ('기타수익', '재고자산감모손실환입'): '',
#    ('기타수익', '재고자산폐기(처분)이익'): '',
#    ('기타수익', '당기손익-공정가치측정\xa0금융자산평가이익'): '',
#    ('기타수익', '자산처분(폐기)이익'): '397',
#    ('기타수익', '자산평가이익'): '',
#    ('기타수익', '자산손상차손환입'): '',
#    ('기타수익', '파생상품이익'): '',
#    ('기타수익', '임대료수익'): '1,168',
#    ('기타수익', '로열티수익'): '',
#    ('기타수익', '수수료수익'): '',
#    ('기타수익', '대손충당금환입'): '',
#    ('기타수익', '충당부채환입액'): '',
#    ('기타수익', '기타'): '12,188',
#    ('기타비용', '기타비용계산에 참여한 계정 펼치기'): '11,799',
#    ('기타비용', '이자비용'): '',
#    ('기타비용', '외환손실'): '',
#    ('기타비용', '재고자산감모손실'): '',
#    ('기타비용', '재고자산폐기(처분)손실'): '',
#    ('기타비용', '당기손익-공정가치측정\xa0금융자산평가손실'): '',
#    ('기타비용', '자산처분(폐기)손실'): '1,070',
#    ('기타비용', '자산평가손실'): '',
#    ('기타비용', '자산손상차손'): '',
#    ('기타비용', '파생상품손실'): '',
#    ('기타비용', '기타대손상각비'): '',
#    ('기타비용', '충당부채전입액'): '',
#    ('기타비용', '기타'): '10,729',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기'): '5,968',
#    ('종속기업,공동지배기업및관계기업관련손익', '지분법손익'): '5,968',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식처분손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식손상관련손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '기타'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '세전계속사업이익'): '296,225',
#    ('종속기업,공동지배기업및관계기업관련손익', '법인세비용'): '29,255',
#    ('종속기업,공동지배기업및관계기업관련손익', '계속영업이익'): '266,970',
#    ('종속기업,공동지배기업및관계기업관련손익', '중단영업이익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '당기순이익'): '266,970',
#    ('종속기업,공동지배기업및관계기업관련손익', '지배주주순이익'): '260,452',
#    ('종속기업,공동지배기업및관계기업관련손익', '비지배주주순이익'): '6,517'},
#   {('매출액', ''): '6.5',
#    ('매출원가', ''): '9.6',
#    ('매출총이익', ''): '1.6',
#    ('판매비와관리비', '판매비와관리비계산에 참여한 계정 펼치기'): '6.8',
#    ('판매비와관리비', '인건비'): '0.9',
#    ('판매비와관리비', '유무형자산상각비'): '5.0',
#    ('판매비와관리비', '연구개발비'): '8.7',
#    ('판매비와관리비', '광고선전비'): '5.3',
#    ('판매비와관리비', '판매비'): '0.8',
#    ('판매비와관리비', '관리비'): '15.3',
#    ('판매비와관리비', '기타원가성비용'): '',
#    ('판매비와관리비', '기타'): '8.8',
#    ('판매비와관리비', '영업이익'): '-10.3',
#    ('판매비와관리비', '영업이익(발표기준)'): '-10.3',
#    ('금융수익', '금융수익계산에 참여한 계정 펼치기'): '5.0',
#    ('금융수익', '이자수익'): '-3.3',
#    ('금융수익', '배당금수익'): '',
#    ('금융수익', '외환이익'): '1.0',
#    ('금융수익', '대손충당금환입액'): '',
#    ('금융수익', '매출채권처분이익'): '',
#    ('금융수익', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('금융수익', '금융자산처분이익'): '',
#    ('금융수익', '금융자산평가이익'): '',
#    ('금융수익', '금융자산손상차손환입'): '',
#    ('금융수익', '파생상품이익'): '92.4',
#    ('금융수익', '기타금융수익'): '',
#    ('금융원가', '금융원가계산에 참여한 계정 펼치기'): '-6.7',
#    ('금융원가', '이자비용'): '-35.5',
#    ('금융원가', '외환손실'): '-6.2',
#    ('금융원가', '대손상각비'): '',
#    ('금융원가', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('금융원가', '매출채권처분손실'): '',
#    ('금융원가', '금융자산처분손실'): '',
#    ('금융원가', '금융자산평가손실'): '',
#    ('금융원가', '금융자산손상차손'): '',
#    ('금융원가', '파생상품손실'): '18.7',
#    ('금융원가', '기타금융원가'): '',
#    ('기타수익', '기타수익계산에 참여한 계정 펼치기'): '11.9',
#    ('기타수익', '이자수익'): '',
#    ('기타수익', '배당금수익'): '-7.8',
#    ('기타수익', '외환이익'): '',
#    ('기타수익', '재고자산감모손실환입'): '',
#    ('기타수익', '재고자산폐기(처분)이익'): '',
#    ('기타수익', '당기손익-공정가치측정\xa0금융자산평가이익'): '',
#    ('기타수익', '자산처분(폐기)이익'): '114.9',
#    ('기타수익', '자산평가이익'): '',
#    ('기타수익', '자산손상차손환입'): '',
#    ('기타수익', '파생상품이익'): '',
#    ('기타수익', '임대료수익'): '-2.8',
#    ('기타수익', '로열티수익'): '',
#    ('기타수익', '수수료수익'): '',
#    ('기타수익', '대손충당금환입'): '',
#    ('기타수익', '충당부채환입액'): '',
#    ('기타수익', '기타'): '11.6',
#    ('기타비용', '기타비용계산에 참여한 계정 펼치기'): '-26.8',
#    ('기타비용', '이자비용'): '',
#    ('기타비용', '외환손실'): '',
#    ('기타비용', '재고자산감모손실'): '',
#    ('기타비용', '재고자산폐기(처분)손실'): '',
#    ('기타비용', '당기손익-공정가치측정\xa0금융자산평가손실'): '',
#    ('기타비용', '자산처분(폐기)손실'): '-63.3',
#    ('기타비용', '자산평가손실'): '',
#    ('기타비용', '자산손상차손'): '',
#    ('기타비용', '파생상품손실'): '',
#    ('기타비용', '기타대손상각비'): '',
#    ('기타비용', '충당부채전입액'): '',
#    ('기타비용', '기타'): '-23.2',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업관련손익계산에 참여한 계정 펼치기'): '-6.4',
#    ('종속기업,공동지배기업및관계기업관련손익', '지분법손익'): '-6.4',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식처분손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '종속기업,공동지배기업및관계기업투자주식손상관련손익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '기타'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '세전계속사업이익'): '-3.9',
#    ('종속기업,공동지배기업및관계기업관련손익', '법인세비용'): '-1.3',
#    ('종속기업,공동지배기업및관계기업관련손익', '계속영업이익'): '-4.2',
#    ('종속기업,공동지배기업및관계기업관련손익', '중단영업이익'): '',
#    ('종속기업,공동지배기업및관계기업관련손익', '당기순이익'): '-4.2',
#    ('종속기업,공동지배기업및관계기업관련손익', '지배주주순이익'): '-4.1',
#    ('종속기업,공동지배기업및관계기업관련손익', '비지배주주순이익'): '-8.5'}],
#  '재무상태표': [{('자산', ''): '4,484,245',
#    ('유동자산', '유동자산계산에 참여한 계정 펼치기'): '2,184,706',
#    ('유동자산', '재고자산'): '521,879',
#    ('유동자산', '유동생물자산'): '',
#    ('유동자산', '유동금융자산'): '655,466',
#    ('유동자산', '매출채권및기타유동채권'): '418,708',
#    ('유동자산', '당기법인세자산'): '',
#    ('유동자산', '계약자산'): '',
#    ('유동자산', '반품(환불)자산'): '',
#    ('유동자산', '배출권'): '',
#    ('유동자산', '기타유동자산'): '91,847',
#    ('유동자산', '현금및현금성자산'): '496,807',
#    ('유동자산', '매각예정비유동자산및처분자산집단'): '',
#    ('비유동자산', '비유동자산계산에 참여한 계정 펼치기'): '2,299,539',
#    ('비유동자산', '유형자산'): '1,680,454',
#    ('비유동자산', '무형자산'): '202,178',
#    ('비유동자산', '비유동생물자산'): '',
#    ('비유동자산', '투자부동산'): '',
#    ('비유동자산', '장기금융자산'): '128,025',
#    ('비유동자산', '관계기업등지분관련투자자산'): '108,939',
#    ('비유동자산', '장기매출채권및기타비유동채권'): '10,285',
#    ('비유동자산', '이연법인세자산'): '51,013',
#    ('비유동자산', '장기당기법인세자산'): '',
#    ('비유동자산', '계약자산'): '',
#    ('비유동자산', '반품(환불)자산'): '',
#    ('비유동자산', '배출권'): '',
#    ('비유동자산', '기타비유동자산'): '118,646',
#    ('비유동자산', '기타금융업자산'): '',
#    ('비유동자산', '부채'): '936,749',
#    ('유동부채', '유동부채계산에 참여한 계정 펼치기'): '783,449',
#    ('유동부채', '단기사채'): '',
#    ('유동부채', '단기차입금'): '51,473',
#    ('유동부채', '유동성장기부채'): '10,892',
#    ('유동부채', '유동금융부채'): '',
#    ('유동부채', '매입채무및기타유동채무'): '587,468',
#    ('유동부채', '유동종업원급여충당부채'): '',
#    ('유동부채', '기타단기충당부채'): '58,449',
#    ('유동부채', '당기법인세부채'): '42,504',
#    ('유동부채', '계약부채'): '',
#    ('유동부채', '반품(환불)부채'): '',
#    ('유동부채', '배출부채'): '',
#    ('유동부채', '기타유동부채'): '32,663',
#    ('유동부채', '매각예정으로분류된처분자산집단에포함된부채'): '',
#    ('비유동부채', '비유동부채계산에 참여한 계정 펼치기'): '153,301',
#    ('비유동부채', '사채'): '5,361',
#    ('비유동부채', '장기차입금'): '338',
#    ('비유동부채', '비유동금융부채'): '35,268',
#    ('비유동부채', '장기매입채무및기타비유동채무'): '27,533',
#    ('비유동부채', '비유동종업원급여충당부채'): '2,684',
#    ('비유동부채', '기타장기충당부채'): '19,285',
#    ('비유동부채', '이연법인세부채'): '51,113',
#    ('비유동부채', '장기당기법인세부채'): '',
#    ('비유동부채', '계약부채'): '',
#    ('비유동부채', '반품(환불)부채'): '',
#    ('비유동부채', '배출부채'): '',
#    ('비유동부채', '기타비유동부채'): '11,718',
#    ('비유동부채', '기타금융업부채'): '',
#    ('비유동부채', '자본'): '3,547,496',
#    ('지배기업주주지분', '지배기업주주지분계산에 참여한 계정 펼치기'): '3,451,861',
#    ('지배기업주주지분', '자본금'): '8,975',
#    ('지배기업주주지분', '신종자본증권'): '',
#    ('지배기업주주지분', '자본잉여금'): '44,039',
#    ('지배기업주주지분', '기타자본'): '866',
#    ('지배기업주주지분', '기타포괄손익누계액'): '18,517',
#    ('지배기업주주지분', '이익잉여금(결손금)'): '3,379,464',
#    ('지배기업주주지분', '비지배주주지분'): '95,635'},
#   {('자산', ''): '4,559,060',
#    ('유동자산', '유동자산계산에 참여한 계정 펼치기'): '1,959,366',
#    ('유동자산', '재고자산'): '516,259',
#    ('유동자산', '유동생물자산'): '',
#    ('유동자산', '유동금융자산'): '233,263',
#    ('유동자산', '매출채권및기타유동채권'): '432,806',
#    ('유동자산', '당기법인세자산'): '',
#    ('유동자산', '계약자산'): '',
#    ('유동자산', '반품(환불)자산'): '',
#    ('유동자산', '배출권'): '',
#    ('유동자산', '기타유동자산'): '84,050',
#    ('유동자산', '현금및현금성자산'): '690,809',
#    ('유동자산', '매각예정비유동자산및처분자산집단'): '2,179',
#    ('비유동자산', '비유동자산계산에 참여한 계정 펼치기'): '2,599,694',
#    ('비유동자산', '유형자산'): '1,872,563',
#    ('비유동자산', '무형자산'): '227,419',
#    ('비유동자산', '비유동생물자산'): '',
#    ('비유동자산', '투자부동산'): '',
#    ('비유동자산', '장기금융자산'): '89,127',
#    ('비유동자산', '관계기업등지분관련투자자산'): '117,674',
#    ('비유동자산', '장기매출채권및기타비유동채권'): '7,834',
#    ('비유동자산', '이연법인세자산'): '102,118',
#    ('비유동자산', '장기당기법인세자산'): '',
#    ('비유동자산', '계약자산'): '',
#    ('비유동자산', '반품(환불)자산'): '',
#    ('비유동자산', '배출권'): '',
#    ('비유동자산', '기타비유동자산'): '182,960',
#    ('비유동자산', '기타금융업자산'): '',
#    ('비유동자산', '부채'): '922,281',
#    ('유동부채', '유동부채계산에 참여한 계정 펼치기'): '757,195',
#    ('유동부채', '단기사채'): '',
#    ('유동부채', '단기차입금'): '71,146',
#    ('유동부채', '유동성장기부채'): '13,089',
#    ('유동부채', '유동금융부채'): '',
#    ('유동부채', '매입채무및기타유동채무'): '535,497',
#    ('유동부채', '유동종업원급여충당부채'): '',
#    ('유동부채', '기타단기충당부채'): '65,249',
#    ('유동부채', '당기법인세부채'): '33,587',
#    ('유동부채', '계약부채'): '',
#    ('유동부채', '반품(환불)부채'): '',
#    ('유동부채', '배출부채'): '',
#    ('유동부채', '기타유동부채'): '38,011',
#    ('유동부채', '매각예정으로분류된처분자산집단에포함된부채'): '617',
#    ('비유동부채', '비유동부채계산에 참여한 계정 펼치기'): '165,087',
#    ('비유동부채', '사채'): '5,376',
#    ('비유동부채', '장기차입금'): '',
#    ('비유동부채', '비유동금융부채'): '37,249',
#    ('비유동부채', '장기매입채무및기타비유동채무'): '54,883',
#    ('비유동부채', '비유동종업원급여충당부채'): '4,566',
#    ('비유동부채', '기타장기충당부채'): '28,785',
#    ('비유동부채', '이연법인세부채'): '6,205',
#    ('비유동부채', '장기당기법인세부채'): '',
#    ('비유동부채', '계약부채'): '',
#    ('비유동부채', '반품(환불)부채'): '',
#    ('비유동부채', '배출부채'): '',
#    ('비유동부채', '기타비유동부채'): '28,024',
#    ('비유동부채', '기타금융업부채'): '',
#    ('비유동부채', '자본'): '3,636,779',
#    ('지배기업주주지분', '지배기업주주지분계산에 참여한 계정 펼치기'): '3,532,338',
#    ('지배기업주주지분', '자본금'): '8,975',
#    ('지배기업주주지분', '신종자본증권'): '',
#    ('지배기업주주지분', '자본잉여금'): '44,039',
#    ('지배기업주주지분', '기타자본'): '990',
#    ('지배기업주주지분', '기타포괄손익누계액'): '11,811',
#    ('지배기업주주지분', '이익잉여금(결손금)'): '3,466,522',
#    ('지배기업주주지분', '비지배주주지분'): '104,441'},
#   {('자산', ''): '5,145,319',
#    ('유동자산', '유동자산계산에 참여한 계정 펼치기'): '2,270,623',
#    ('유동자산', '재고자산'): '517,549',
#    ('유동자산', '유동생물자산'): '',
#    ('유동자산', '유동금융자산'): '589,462',
#    ('유동자산', '매출채권및기타유동채권'): '532,460',
#    ('유동자산', '당기법인세자산'): '',
#    ('유동자산', '계약자산'): '',
#    ('유동자산', '반품(환불)자산'): '',
#    ('유동자산', '배출권'): '',
#    ('유동자산', '기타유동자산'): '94,096',
#    ('유동자산', '현금및현금성자산'): '537,056',
#    ('유동자산', '매각예정비유동자산및처분자산집단'): '',
#    ('비유동자산', '비유동자산계산에 참여한 계정 펼치기'): '2,874,697',
#    ('비유동자산', '유형자산'): '2,059,452',
#    ('비유동자산', '무형자산'): '237,386',
#    ('비유동자산', '비유동생물자산'): '',
#    ('비유동자산', '투자부동산'): '',
#    ('비유동자산', '장기금융자산'): '117,567',
#    ('비유동자산', '관계기업등지분관련투자자산'): '125,921',
#    ('비유동자산', '장기매출채권및기타비유동채권'): '8,115',
#    ('비유동자산', '이연법인세자산'): '142,365',
#    ('비유동자산', '장기당기법인세자산'): '',
#    ('비유동자산', '계약자산'): '',
#    ('비유동자산', '반품(환불)자산'): '',
#    ('비유동자산', '배출권'): '',
#    ('비유동자산', '기타비유동자산'): '183,892',
#    ('비유동자산', '기타금융업자산'): '',
#    ('비유동자산', '부채'): '1,123,399',
#    ('유동부채', '유동부채계산에 참여한 계정 펼치기'): '933,263',
#    ('유동부채', '단기사채'): '',
#    ('유동부채', '단기차입금'): '131,725',
#    ('유동부채', '유동성장기부채'): '22,073',
#    ('유동부채', '유동금융부채'): '',
#    ('유동부채', '매입채무및기타유동채무'): '615,226',
#    ('유동부채', '유동종업원급여충당부채'): '',
#    ('유동부채', '기타단기충당부채'): '82,165',
#    ('유동부채', '당기법인세부채'): '43,402',
#    ('유동부채', '계약부채'): '',
#    ('유동부채', '반품(환불)부채'): '',
#    ('유동부채', '배출부채'): '',
#    ('유동부채', '기타유동부채'): '38,673',
#    ('유동부채', '매각예정으로분류된처분자산집단에포함된부채'): '',
#    ('비유동부채', '비유동부채계산에 참여한 계정 펼치기'): '190,136',
#    ('비유동부채', '사채'): '145',
#    ('비유동부채', '장기차입금'): '65',
#    ('비유동부채', '비유동금융부채'): '39,293',
#    ('비유동부채', '장기매입채무및기타비유동채무'): '55,105',
#    ('비유동부채', '비유동종업원급여충당부채'): '5,214',
#    ('비유동부채', '기타장기충당부채'): '31,200',
#    ('비유동부채', '이연법인세부채'): '5,282',
#    ('비유동부채', '장기당기법인세부채'): '',
#    ('비유동부채', '계약부채'): '',
#    ('비유동부채', '반품(환불)부채'): '',
#    ('비유동부채', '배출부채'): '',
#    ('비유동부채', '기타비유동부채'): '53,830',
#    ('비유동부채', '기타금융업부채'): '',
#    ('비유동부채', '자본'): '4,021,921',
#    ('지배기업주주지분', '지배기업주주지분계산에 참여한 계정 펼치기'): '3,916,876',
#    ('지배기업주주지분', '자본금'): '8,975',
#    ('지배기업주주지분', '신종자본증권'): '',
#    ('지배기업주주지분', '자본잉여금'): '44,039',
#    ('지배기업주주지분', '기타자본'): '-17,249',
#    ('지배기업주주지분', '기타포괄손익누계액'): '175,979',
#    ('지배기업주주지분', '이익잉여금(결손금)'): '3,705,132',
#    ('지배기업주주지분', '비지배주주지분'): '105,045'},
#   {('자산', ''): '5,236,596',
#    ('유동자산', '유동자산계산에 참여한 계정 펼치기'): '2,294,409',
#    ('유동자산', '재고자산'): '503,324',
#    ('유동자산', '유동생물자산'): '',
#    ('유동자산', '유동금융자산'): '550,643',
#    ('유동자산', '매출채권및기타유동채권'): '582,771',
#    ('유동자산', '당기법인세자산'): '',
#    ('유동자산', '계약자산'): '',
#    ('유동자산', '반품(환불)자산'): '',
#    ('유동자산', '배출권'): '',
#    ('유동자산', '기타유동자산'): '118,314',
#    ('유동자산', '현금및현금성자산'): '533,995',
#    ('유동자산', '매각예정비유동자산및처분자산집단'): '5,361',
#    ('비유동자산', '비유동자산계산에 참여한 계정 펼치기'): '2,942,187',
#    ('비유동자산', '유형자산'): '2,048,611',
#    ('비유동자산', '무형자산'): '264,691',
#    ('비유동자산', '비유동생물자산'): '',
#    ('비유동자산', '투자부동산'): '',
#    ('비유동자산', '장기금융자산'): '161,075',
#    ('비유동자산', '관계기업등지분관련투자자산'): '132,968',
#    ('비유동자산', '장기매출채권및기타비유동채권'): '',
#    ('비유동자산', '이연법인세자산'): '151,484',
#    ('비유동자산', '장기당기법인세자산'): '',
#    ('비유동자산', '계약자산'): '',
#    ('비유동자산', '반품(환불)자산'): '',
#    ('비유동자산', '배출권'): '',
#    ('비유동자산', '기타비유동자산'): '183,358',
#    ('비유동자산', '기타금융업자산'): '',
#    ('비유동자산', '부채'): '1,101,581',
#    ('유동부채', '유동부채계산에 참여한 계정 펼치기'): '872,593',
#    ('유동부채', '단기사채'): '',
#    ('유동부채', '단기차입금'): '98,468',
#    ('유동부채', '유동성장기부채'): '11,700',
#    ('유동부채', '유동금융부채'): '',
#    ('유동부채', '매입채무및기타유동채무'): '587,139',
#    ('유동부채', '유동종업원급여충당부채'): '',
#    ('유동부채', '기타단기충당부채'): '68,381',
#    ('유동부채', '당기법인세부채'): '61,896',
#    ('유동부채', '계약부채'): '',
#    ('유동부채', '반품(환불)부채'): '',
#    ('유동부채', '배출부채'): '',
#    ('유동부채', '기타유동부채'): '43,549',
#    ('유동부채', '매각예정으로분류된처분자산집단에포함된부채'): '1,459',
#    ('비유동부채', '비유동부채계산에 참여한 계정 펼치기'): '228,988',
#    ('비유동부채', '사채'): '139',
#    ('비유동부채', '장기차입금'): '20,019',
#    ('비유동부채', '비유동금융부채'): '36,395',
#    ('비유동부채', '장기매입채무및기타비유동채무'): '58,255',
#    ('비유동부채', '비유동종업원급여충당부채'): '5,249',
#    ('비유동부채', '기타장기충당부채'): '31,335',
#    ('비유동부채', '이연법인세부채'): '4,480',
#    ('비유동부채', '장기당기법인세부채'): '',
#    ('비유동부채', '계약부채'): '',
#    ('비유동부채', '반품(환불)부채'): '',
#    ('비유동부채', '배출부채'): '',
#    ('비유동부채', '기타비유동부채'): '73,115',
#    ('비유동부채', '기타금융업부채'): '',
#    ('비유동부채', '자본'): '4,135,015',
#    ('지배기업주주지분', '지배기업주주지분계산에 참여한 계정 펼치기'): '4,020,011',
#    ('지배기업주주지분', '자본금'): '8,975',
#    ('지배기업주주지분', '신종자본증권'): '',
#    ('지배기업주주지분', '자본잉여금'): '44,039',
#    ('지배기업주주지분', '기타자본'): '-62,920',
#    ('지배기업주주지분', '기타포괄손익누계액'): '177,124',
#    ('지배기업주주지분', '이익잉여금(결손금)'): '3,852,793',
#    ('지배기업주주지분', '비지배주주지분'): '115,004'}],
#  '현금흐름표': [{('영업활동으로인한현금흐름', ''): '621,813',
#    ('당기순손익', ''): '556,541',
#    ('법인세비용차감전계속사업이익', ''): '',
#    ('현금유출이없는비용등가산', '현금유출이없는비용등가산계산에 참여한 계정 펼치기'): '497,297',
#    ('현금유출이없는비용등가산', '퇴직급여'): '14,401',
#    ('현금유출이없는비용등가산', '종업원급여'): '',
#    ('현금유출이없는비용등가산', '주식보상비'): '',
#    ('현금유출이없는비용등가산', '대손상각비'): '88',
#    ('현금유출이없는비용등가산', '감가상각비'): '359,521',
#    ('현금유출이없는비용등가산', '무형자산상각비'): '31,556',
#    ('현금유출이없는비용등가산', '계약부채전입액'): '',
#    ('현금유출이없는비용등가산', '반품(환불)부채전입액'): '',
#    ('현금유출이없는비용등가산', '배출부채전입액'): '',
#    ('현금유출이없는비용등가산', '충당부채전입액'): '',
#    ('현금유출이없는비용등가산', '외환손실'): '',
#    ('현금유출이없는비용등가산', '기타의대손상각비'): '',
#    ('현금유출이없는비용등가산', '금융원가'): '43,363',
#    ('현금유출이없는비용등가산', '이자비용'): '',
#    ('현금유출이없는비용등가산', '배당금지급'): '',
#    ('현금유출이없는비용등가산', '매출채권처분손실'): '',
#    ('현금유출이없는비용등가산', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('현금유출이없는비용등가산', '금융자산처분손실'): '',
#    ('현금유출이없는비용등가산', '금융자산평가손실'): '',
#    ('현금유출이없는비용등가산', '금융자산손상차손'): '',
#    ('현금유출이없는비용등가산', '파생상품손실'): '',
#    ('현금유출이없는비용등가산', '금융부채관련손실'): '',
#    ('현금유출이없는비용등가산', '사채상환손실'): '',
#    ('현금유출이없는비용등가산', '재고자산감모손실'): '',
#    ('현금유출이없는비용등가산', '재고자산폐기(처분)손실'): '',
#    ('현금유출이없는비용등가산', '자산처분(폐기)손실'): '613',
#    ('현금유출이없는비용등가산', '투자자산평가손실'): '',
#    ('현금유출이없는비용등가산', '자산재평가손실'): '',
#    ('현금유출이없는비용등가산', '자산손상차손'): '44,088',
#    ('현금유출이없는비용등가산', '지분법관련손실'): '',
#    ('현금유출이없는비용등가산', '종속기업관련손실'): '',
#    ('현금유출이없는비용등가산', '관계기업관련손익'): '',
#    ('현금유출이없는비용등가산', '법인세비용'): '',
#    ('현금유출이없는비용등가산', '기타비용'): '3,669',
#    ('(현금유입이없는수익등차감)', '(현금유입이없는수익등차감)계산에 참여한 계정 펼치기'): '166,562',
#    ('(현금유입이없는수익등차감)', '외환이익'): '',
#    ('(현금유입이없는수익등차감)', '대손충당금환입액'): '',
#    ('(현금유입이없는수익등차감)', '금융수익'): '57,783',
#    ('(현금유입이없는수익등차감)', '이자수익'): '',
#    ('(현금유입이없는수익등차감)', '배당금수익'): '4,146',
#    ('(현금유입이없는수익등차감)', '매출채권처분이익'): '',
#    ('(현금유입이없는수익등차감)', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산처분이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '파생상품이익'): '',
#    ('(현금유입이없는수익등차감)', '금융부채관련이익'): '',
#    ('(현금유입이없는수익등차감)', '사채상환이익'): '',
#    ('(현금유입이없는수익등차감)', '퇴직급여충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '계약부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '반품(환불)부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '배출부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '주식보상비환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산감모손실환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산폐기(처분)이익'): '',
#    ('(현금유입이없는수익등차감)', '자산처분(폐기)이익'): '1,591',
#    ('(현금유입이없는수익등차감)', '투자자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산재평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '지분법관련이익'): '10,906',
#    ('(현금유입이없는수익등차감)', '종속회사관련이익'): '',
#    ('(현금유입이없는수익등차감)', '관계기업관련손익'): '',
#    ('(현금유입이없는수익등차감)', '법인세수익'): '92,136',
#    ('(현금유입이없는수익등차감)', '기타수익'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)',
#     '영업활동으로인한자산부채변동(운전자본변동)계산에 참여한 계정 펼치기'): '-169,989',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '자산의감소(증가)'): '-69,755',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '부채의증가(감소)'): '-86,757',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '정부보조금등의변동'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '기타운전자본의변동'): '-13,478',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '*영업에서창출된현금흐름'): '717,286',
#    ('기타영업활동으로인한현금흐름', '기타영업활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-95,472',
#    ('기타영업활동으로인한현금흐름', '이자수입'): '21,368',
#    ('기타영업활동으로인한현금흐름', '이자지급(-)'): '-7,145',
#    ('기타영업활동으로인한현금흐름', '배당금수입'): '5,294',
#    ('기타영업활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타영업활동으로인한현금흐름', '법인세환입'): '',
#    ('기타영업활동으로인한현금흐름', '법인세납부(-)'): '-114,989',
#    ('기타영업활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타영업활동으로인한현금흐름', '투자활동으로인한현금흐름'): '-316,028',
#    ('투자활동으로인한현금유입액', '투자활동으로인한현금유입액계산에 참여한 계정 펼치기'): '274,660',
#    ('투자활동으로인한현금유입액', '유동금융자산의감소'): '189,385',
#    ('투자활동으로인한현금유입액', '장기금융상품의감소'): '82,729',
#    ('투자활동으로인한현금유입액', '매도가능금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '만기보유금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '장기대여금의감소'): '',
#    ('투자활동으로인한현금유입액', '파생상품의변동'): '',
#    ('투자활동으로인한현금유입액', '기타비유동금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '관계기업등지분관련투자자산의감소'): '132',
#    ('투자활동으로인한현금유입액', '유형자산의감소'): '2,179',
#    ('투자활동으로인한현금유입액', '무형자산의감소'): '235',
#    ('투자활동으로인한현금유입액', '생물자산의감소'): '',
#    ('투자활동으로인한현금유입액', '투자부동산의감소'): '',
#    ('투자활동으로인한현금유입액', '기타투자활동으로인한현금유입액'): '',
#    ('(투자활동으로인한현금유출액)', '(투자활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '590,688',
#    ('(투자활동으로인한현금유출액)', '유동금융자산의증가'): '1,959',
#    ('(투자활동으로인한현금유출액)', '장기금융상품의증가'): '43,938',
#    ('(투자활동으로인한현금유출액)', '매도가능금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '만기보유금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '장기대여금의증가'): '',
#    ('(투자활동으로인한현금유출액)', '파생상품의변동'): '',
#    ('(투자활동으로인한현금유출액)', '기타비유동금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '관계기업등지분관련투자자산의증가'): '9,080',
#    ('(투자활동으로인한현금유출액)', '유형자산의증가'): '494,304',
#    ('(투자활동으로인한현금유출액)', '무형자산의증가'): '36,963',
#    ('(투자활동으로인한현금유출액)', '생물자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '투자부동산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '기타투자활동으로인한현금유출액'): '4,444',
#    ('기타투자활동으로인한현금흐름', '기타투자활동으로인한현금흐름계산에 참여한 계정 펼치기'): '',
#    ('기타투자활동으로인한현금흐름', '이자수입'): '',
#    ('기타투자활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '배당금수입'): '',
#    ('기타투자활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '법인세환입'): '',
#    ('기타투자활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타투자활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타투자활동으로인한현금흐름', '재무활동으로인한현금흐름'): '-193,900',
#    ('재무활동으로인한현금유입액', '재무활동으로인한현금유입액계산에 참여한 계정 펼치기'): '2,720',
#    ('재무활동으로인한현금유입액', '사채의증가'): '',
#    ('재무활동으로인한현금유입액', '차입금의증가'): '2,720',
#    ('재무활동으로인한현금유입액', '미지급금의증가'): '',
#    ('재무활동으로인한현금유입액', '유동성장기부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타금융부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타부채의증가'): '',
#    ('재무활동으로인한현금유입액', '유상증자'): '',
#    ('재무활동으로인한현금유입액', '자기주식의처분'): '',
#    ('재무활동으로인한현금유입액', '주식매입선택권의행사'): '',
#    ('재무활동으로인한현금유입액', '자본구성항목의증가'): '',
#    ('재무활동으로인한현금유입액', '기타재무활동으로인한현금유입액'): '',
#    ('(재무활동으로인한현금유출액)', '(재무활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '98,476',
#    ('(재무활동으로인한현금유출액)', '사채의감소'): '15,085',
#    ('(재무활동으로인한현금유출액)', '차입금의감소'): '83,391',
#    ('(재무활동으로인한현금유출액)', '미지급금의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유동성장기부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타금융부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유상감자'): '',
#    ('(재무활동으로인한현금유출액)', '자기주식의취득'): '',
#    ('(재무활동으로인한현금유출액)', '자본구성항목의감소'): '0',
#    ('(재무활동으로인한현금유출액)', '기타재무활동으로인한현금유출액'): '',
#    ('기타재무활동으로인한현금흐름', '기타재무활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-98,144',
#    ('기타재무활동으로인한현금흐름', '이자수입'): '',
#    ('기타재무활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타재무활동으로인한현금흐름', '배당금수입'): '',
#    ('기타재무활동으로인한현금흐름', '배당금지급(-)'): '-98,144',
#    ('기타재무활동으로인한현금흐름', '법인세환입'): '',
#    ('기타재무활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타재무활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '영업투자재무활동기타현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '연결범위변동으로인한현금의증가'): '',
#    ('기타재무활동으로인한현금흐름', '환율변동효과'): '-5,392',
#    ('기타재무활동으로인한현금흐름', '현금및현금성자산의증가'): '106,493',
#    ('기타재무활동으로인한현금흐름', '기초현금및현금성자산'): '390,314',
#    ('기타재무활동으로인한현금흐름', '기말현금및현금성자산'): '496,807'},
#   {('영업활동으로인한현금흐름', ''): '441,374',
#    ('당기순손익', ''): '154,871',
#    ('법인세비용차감전계속사업이익', ''): '',
#    ('현금유출이없는비용등가산', '현금유출이없는비용등가산계산에 참여한 계정 펼치기'): '483,129',
#    ('현금유출이없는비용등가산', '퇴직급여'): '11,574',
#    ('현금유출이없는비용등가산', '종업원급여'): '',
#    ('현금유출이없는비용등가산', '주식보상비'): '',
#    ('현금유출이없는비용등가산', '대손상각비'): '630',
#    ('현금유출이없는비용등가산', '감가상각비'): '355,324',
#    ('현금유출이없는비용등가산', '무형자산상각비'): '31,341',
#    ('현금유출이없는비용등가산', '계약부채전입액'): '',
#    ('현금유출이없는비용등가산', '반품(환불)부채전입액'): '',
#    ('현금유출이없는비용등가산', '배출부채전입액'): '',
#    ('현금유출이없는비용등가산', '충당부채전입액'): '',
#    ('현금유출이없는비용등가산', '외환손실'): '',
#    ('현금유출이없는비용등가산', '기타의대손상각비'): '',
#    ('현금유출이없는비용등가산', '금융원가'): '30,768',
#    ('현금유출이없는비용등가산', '이자비용'): '',
#    ('현금유출이없는비용등가산', '배당금지급'): '',
#    ('현금유출이없는비용등가산', '매출채권처분손실'): '',
#    ('현금유출이없는비용등가산', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('현금유출이없는비용등가산', '금융자산처분손실'): '',
#    ('현금유출이없는비용등가산', '금융자산평가손실'): '',
#    ('현금유출이없는비용등가산', '금융자산손상차손'): '',
#    ('현금유출이없는비용등가산', '파생상품손실'): '',
#    ('현금유출이없는비용등가산', '금융부채관련손실'): '',
#    ('현금유출이없는비용등가산', '사채상환손실'): '',
#    ('현금유출이없는비용등가산', '재고자산감모손실'): '',
#    ('현금유출이없는비용등가산', '재고자산폐기(처분)손실'): '',
#    ('현금유출이없는비용등가산', '자산처분(폐기)손실'): '858',
#    ('현금유출이없는비용등가산', '투자자산평가손실'): '',
#    ('현금유출이없는비용등가산', '자산재평가손실'): '',
#    ('현금유출이없는비용등가산', '자산손상차손'): '50,376',
#    ('현금유출이없는비용등가산', '지분법관련손실'): '',
#    ('현금유출이없는비용등가산', '종속기업관련손실'): '',
#    ('현금유출이없는비용등가산', '관계기업관련손익'): '',
#    ('현금유출이없는비용등가산', '법인세비용'): '',
#    ('현금유출이없는비용등가산', '기타비용'): '2,257',
#    ('(현금유입이없는수익등차감)', '(현금유입이없는수익등차감)계산에 참여한 계정 펼치기'): '117,933',
#    ('(현금유입이없는수익등차감)', '외환이익'): '',
#    ('(현금유입이없는수익등차감)', '대손충당금환입액'): '',
#    ('(현금유입이없는수익등차감)', '금융수익'): '61,561',
#    ('(현금유입이없는수익등차감)', '이자수익'): '',
#    ('(현금유입이없는수익등차감)', '배당금수익'): '1,642',
#    ('(현금유입이없는수익등차감)', '매출채권처분이익'): '',
#    ('(현금유입이없는수익등차감)', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산처분이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '파생상품이익'): '',
#    ('(현금유입이없는수익등차감)', '금융부채관련이익'): '',
#    ('(현금유입이없는수익등차감)', '사채상환이익'): '',
#    ('(현금유입이없는수익등차감)', '퇴직급여충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '계약부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '반품(환불)부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '배출부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '주식보상비환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산감모손실환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산폐기(처분)이익'): '',
#    ('(현금유입이없는수익등차감)', '자산처분(폐기)이익'): '1,047',
#    ('(현금유입이없는수익등차감)', '투자자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산재평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '지분법관련이익'): '8,876',
#    ('(현금유입이없는수익등차감)', '종속회사관련이익'): '',
#    ('(현금유입이없는수익등차감)', '관계기업관련손익'): '',
#    ('(현금유입이없는수익등차감)', '법인세수익'): '44,808',
#    ('(현금유입이없는수익등차감)', '기타수익'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)',
#     '영업활동으로인한자산부채변동(운전자본변동)계산에 참여한 계정 펼치기'): '-54,587',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '자산의감소(증가)'): '-33,616',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '부채의증가(감소)'): '-21,443',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '정부보조금등의변동'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '기타운전자본의변동'): '472',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '*영업에서창출된현금흐름'): '465,479',
#    ('기타영업활동으로인한현금흐름', '기타영업활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-24,105',
#    ('기타영업활동으로인한현금흐름', '이자수입'): '47,860',
#    ('기타영업활동으로인한현금흐름', '이자지급(-)'): '-8,447',
#    ('기타영업활동으로인한현금흐름', '배당금수입'): '2,692',
#    ('기타영업활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타영업활동으로인한현금흐름', '법인세환입'): '',
#    ('기타영업활동으로인한현금흐름', '법인세납부(-)'): '-66,210',
#    ('기타영업활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타영업활동으로인한현금흐름', '투자활동으로인한현금흐름'): '-169,228',
#    ('투자활동으로인한현금유입액', '투자활동으로인한현금유입액계산에 참여한 계정 펼치기'): '507,188',
#    ('투자활동으로인한현금유입액', '유동금융자산의감소'): '460,098',
#    ('투자활동으로인한현금유입액', '장기금융상품의감소'): '45,654',
#    ('투자활동으로인한현금유입액', '매도가능금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '만기보유금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '장기대여금의감소'): '',
#    ('투자활동으로인한현금유입액', '파생상품의변동'): '',
#    ('투자활동으로인한현금유입액', '기타비유동금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '관계기업등지분관련투자자산의감소'): '335',
#    ('투자활동으로인한현금유입액', '유형자산의감소'): '983',
#    ('투자활동으로인한현금유입액', '무형자산의감소'): '117',
#    ('투자활동으로인한현금유입액', '생물자산의감소'): '',
#    ('투자활동으로인한현금유입액', '투자부동산의감소'): '',
#    ('투자활동으로인한현금유입액', '기타투자활동으로인한현금유입액'): '',
#    ('(투자활동으로인한현금유출액)', '(투자활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '676,416',
#    ('(투자활동으로인한현금유출액)', '유동금융자산의증가'): '4,506',
#    ('(투자활동으로인한현금유출액)', '장기금융상품의증가'): '53,078',
#    ('(투자활동으로인한현금유출액)', '매도가능금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '만기보유금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '장기대여금의증가'): '',
#    ('(투자활동으로인한현금유출액)', '파생상품의변동'): '',
#    ('(투자활동으로인한현금유출액)', '기타비유동금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '관계기업등지분관련투자자산의증가'): '787',
#    ('(투자활동으로인한현금유출액)', '유형자산의증가'): '576,113',
#    ('(투자활동으로인한현금유출액)', '무형자산의증가'): '29,229',
#    ('(투자활동으로인한현금유출액)', '생물자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '투자부동산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '기타투자활동으로인한현금유출액'): '12,704',
#    ('기타투자활동으로인한현금흐름', '기타투자활동으로인한현금흐름계산에 참여한 계정 펼치기'): '',
#    ('기타투자활동으로인한현금흐름', '이자수입'): '',
#    ('기타투자활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '배당금수입'): '',
#    ('기타투자활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '법인세환입'): '',
#    ('기타투자활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타투자활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타투자활동으로인한현금흐름', '재무활동으로인한현금흐름'): '-85,931',
#    ('재무활동으로인한현금유입액', '재무활동으로인한현금유입액계산에 참여한 계정 펼치기'): '25,001',
#    ('재무활동으로인한현금유입액', '사채의증가'): '',
#    ('재무활동으로인한현금유입액', '차입금의증가'): '25,001',
#    ('재무활동으로인한현금유입액', '미지급금의증가'): '',
#    ('재무활동으로인한현금유입액', '유동성장기부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타금융부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타부채의증가'): '',
#    ('재무활동으로인한현금유입액', '유상증자'): '',
#    ('재무활동으로인한현금유입액', '자기주식의처분'): '',
#    ('재무활동으로인한현금유입액', '주식매입선택권의행사'): '',
#    ('재무활동으로인한현금유입액', '자본구성항목의증가'): '',
#    ('재무활동으로인한현금유입액', '기타재무활동으로인한현금유입액'): '',
#    ('(재무활동으로인한현금유출액)', '(재무활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '12,287',
#    ('(재무활동으로인한현금유출액)', '사채의감소'): '12,196',
#    ('(재무활동으로인한현금유출액)', '차입금의감소'): '',
#    ('(재무활동으로인한현금유출액)', '미지급금의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유동성장기부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타금융부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유상감자'): '',
#    ('(재무활동으로인한현금유출액)', '자기주식의취득'): '',
#    ('(재무활동으로인한현금유출액)', '자본구성항목의감소'): '91',
#    ('(재무활동으로인한현금유출액)', '기타재무활동으로인한현금유출액'): '',
#    ('기타재무활동으로인한현금흐름', '기타재무활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-98,645',
#    ('기타재무활동으로인한현금흐름', '이자수입'): '',
#    ('기타재무활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타재무활동으로인한현금흐름', '배당금수입'): '',
#    ('기타재무활동으로인한현금흐름', '배당금지급(-)'): '-98,645',
#    ('기타재무활동으로인한현금흐름', '법인세환입'): '',
#    ('기타재무활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타재무활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '영업투자재무활동기타현금흐름'): '-142',
#    ('기타재무활동으로인한현금흐름', '연결범위변동으로인한현금의증가'): '',
#    ('기타재무활동으로인한현금흐름', '환율변동효과'): '7,928',
#    ('기타재무활동으로인한현금흐름', '현금및현금성자산의증가'): '194,002',
#    ('기타재무활동으로인한현금흐름', '기초현금및현금성자산'): '496,807',
#    ('기타재무활동으로인한현금흐름', '기말현금및현금성자산'): '690,809'},
#   {('영업활동으로인한현금흐름', ''): '729,826',
#    ('당기순손익', ''): '344,514',
#    ('법인세비용차감전계속사업이익', ''): '',
#    ('현금유출이없는비용등가산', '현금유출이없는비용등가산계산에 참여한 계정 펼치기'): '518,542',
#    ('현금유출이없는비용등가산', '퇴직급여'): '15,713',
#    ('현금유출이없는비용등가산', '종업원급여'): '',
#    ('현금유출이없는비용등가산', '주식보상비'): '',
#    ('현금유출이없는비용등가산', '대손상각비'): '617',
#    ('현금유출이없는비용등가산', '감가상각비'): '396,500',
#    ('현금유출이없는비용등가산', '무형자산상각비'): '29,808',
#    ('현금유출이없는비용등가산', '계약부채전입액'): '',
#    ('현금유출이없는비용등가산', '반품(환불)부채전입액'): '',
#    ('현금유출이없는비용등가산', '배출부채전입액'): '',
#    ('현금유출이없는비용등가산', '충당부채전입액'): '',
#    ('현금유출이없는비용등가산', '외환손실'): '',
#    ('현금유출이없는비용등가산', '기타의대손상각비'): '',
#    ('현금유출이없는비용등가산', '금융원가'): '38,793',
#    ('현금유출이없는비용등가산', '이자비용'): '',
#    ('현금유출이없는비용등가산', '배당금지급'): '',
#    ('현금유출이없는비용등가산', '매출채권처분손실'): '',
#    ('현금유출이없는비용등가산', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('현금유출이없는비용등가산', '금융자산처분손실'): '',
#    ('현금유출이없는비용등가산', '금융자산평가손실'): '',
#    ('현금유출이없는비용등가산', '금융자산손상차손'): '',
#    ('현금유출이없는비용등가산', '파생상품손실'): '',
#    ('현금유출이없는비용등가산', '금융부채관련손실'): '',
#    ('현금유출이없는비용등가산', '사채상환손실'): '',
#    ('현금유출이없는비용등가산', '재고자산감모손실'): '',
#    ('현금유출이없는비용등가산', '재고자산폐기(처분)손실'): '',
#    ('현금유출이없는비용등가산', '자산처분(폐기)손실'): '1,240',
#    ('현금유출이없는비용등가산', '투자자산평가손실'): '',
#    ('현금유출이없는비용등가산', '자산재평가손실'): '',
#    ('현금유출이없는비용등가산', '자산손상차손'): '',
#    ('현금유출이없는비용등가산', '지분법관련손실'): '',
#    ('현금유출이없는비용등가산', '종속기업관련손실'): '',
#    ('현금유출이없는비용등가산', '관계기업관련손익'): '',
#    ('현금유출이없는비용등가산', '법인세비용'): '30,784',
#    ('현금유출이없는비용등가산', '기타비용'): '5,087',
#    ('(현금유입이없는수익등차감)', '(현금유입이없는수익등차감)계산에 참여한 계정 펼치기'): '89,072',
#    ('(현금유입이없는수익등차감)', '외환이익'): '',
#    ('(현금유입이없는수익등차감)', '대손충당금환입액'): '',
#    ('(현금유입이없는수익등차감)', '금융수익'): '74,124',
#    ('(현금유입이없는수익등차감)', '이자수익'): '',
#    ('(현금유입이없는수익등차감)', '배당금수익'): '1,350',
#    ('(현금유입이없는수익등차감)', '매출채권처분이익'): '',
#    ('(현금유입이없는수익등차감)', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산처분이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '파생상품이익'): '',
#    ('(현금유입이없는수익등차감)', '금융부채관련이익'): '',
#    ('(현금유입이없는수익등차감)', '사채상환이익'): '',
#    ('(현금유입이없는수익등차감)', '퇴직급여충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '계약부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '반품(환불)부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '배출부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '주식보상비환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산감모손실환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산폐기(처분)이익'): '',
#    ('(현금유입이없는수익등차감)', '자산처분(폐기)이익'): '816',
#    ('(현금유입이없는수익등차감)', '투자자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산재평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산손상차손환입'): '5,271',
#    ('(현금유입이없는수익등차감)', '지분법관련이익'): '7,510',
#    ('(현금유입이없는수익등차감)', '종속회사관련이익'): '',
#    ('(현금유입이없는수익등차감)', '관계기업관련손익'): '',
#    ('(현금유입이없는수익등차감)', '법인세수익'): '',
#    ('(현금유입이없는수익등차감)', '기타수익'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)',
#     '영업활동으로인한자산부채변동(운전자본변동)계산에 참여한 계정 펼치기'): '-15,676',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '자산의감소(증가)'): '-9,666',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '부채의증가(감소)'): '-4,329',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '정부보조금등의변동'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '기타운전자본의변동'): '-1,680',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '*영업에서창출된현금흐름'): '758,309',
#    ('기타영업활동으로인한현금흐름', '기타영업활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-28,483',
#    ('기타영업활동으로인한현금흐름', '이자수입'): '40,084',
#    ('기타영업활동으로인한현금흐름', '이자지급(-)'): '-6,750',
#    ('기타영업활동으로인한현금흐름', '배당금수입'): '2,685',
#    ('기타영업활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타영업활동으로인한현금흐름', '법인세환입'): '',
#    ('기타영업활동으로인한현금흐름', '법인세납부(-)'): '-64,500',
#    ('기타영업활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타영업활동으로인한현금흐름', '투자활동으로인한현금흐름'): '-853,817',
#    ('투자활동으로인한현금유입액', '투자활동으로인한현금유입액계산에 참여한 계정 펼치기'): '57,444',
#    ('투자활동으로인한현금유입액', '유동금융자산의감소'): '13,205',
#    ('투자활동으로인한현금유입액', '장기금융상품의감소'): '41,000',
#    ('투자활동으로인한현금유입액', '매도가능금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '만기보유금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '장기대여금의감소'): '',
#    ('투자활동으로인한현금유입액', '파생상품의변동'): '',
#    ('투자활동으로인한현금유입액', '기타비유동금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '관계기업등지분관련투자자산의감소'): '332',
#    ('투자활동으로인한현금유입액', '유형자산의감소'): '1,562',
#    ('투자활동으로인한현금유입액', '무형자산의감소'): '159',
#    ('투자활동으로인한현금유입액', '생물자산의감소'): '',
#    ('투자활동으로인한현금유입액', '투자부동산의감소'): '',
#    ('투자활동으로인한현금유입액', '기타투자활동으로인한현금유입액'): '1,187',
#    ('(투자활동으로인한현금유출액)', '(투자활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '911,261',
#    ('(투자활동으로인한현금유출액)', '유동금융자산의증가'): '332,433',
#    ('(투자활동으로인한현금유출액)', '장기금융상품의증가'): '39,873',
#    ('(투자활동으로인한현금유출액)', '매도가능금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '만기보유금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '장기대여금의증가'): '',
#    ('(투자활동으로인한현금유출액)', '파생상품의변동'): '',
#    ('(투자활동으로인한현금유출액)', '기타비유동금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '관계기업등지분관련투자자산의증가'): '117',
#    ('(투자활동으로인한현금유출액)', '유형자산의증가'): '514,064',
#    ('(투자활동으로인한현금유출액)', '무형자산의증가'): '23,353',
#    ('(투자활동으로인한현금유출액)', '생물자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '투자부동산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '기타투자활동으로인한현금유출액'): '1,422',
#    ('기타투자활동으로인한현금흐름', '기타투자활동으로인한현금흐름계산에 참여한 계정 펼치기'): '',
#    ('기타투자활동으로인한현금흐름', '이자수입'): '',
#    ('기타투자활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '배당금수입'): '',
#    ('기타투자활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '법인세환입'): '',
#    ('기타투자활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타투자활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타투자활동으로인한현금흐름', '재무활동으로인한현금흐름'): '-77,972',
#    ('재무활동으로인한현금유입액', '재무활동으로인한현금유입액계산에 참여한 계정 펼치기'): '62,763',
#    ('재무활동으로인한현금유입액', '사채의증가'): '',
#    ('재무활동으로인한현금유입액', '차입금의증가'): '62,763',
#    ('재무활동으로인한현금유입액', '미지급금의증가'): '',
#    ('재무활동으로인한현금유입액', '유동성장기부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타금융부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타부채의증가'): '',
#    ('재무활동으로인한현금유입액', '유상증자'): '',
#    ('재무활동으로인한현금유입액', '자기주식의처분'): '',
#    ('재무활동으로인한현금유입액', '주식매입선택권의행사'): '',
#    ('재무활동으로인한현금유입액', '자본구성항목의증가'): '',
#    ('재무활동으로인한현금유입액', '기타재무활동으로인한현금유입액'): '',
#    ('(재무활동으로인한현금유출액)', '(재무활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '31,848',
#    ('(재무활동으로인한현금유출액)', '사채의감소'): '13,645',
#    ('(재무활동으로인한현금유출액)', '차입금의감소'): '',
#    ('(재무활동으로인한현금유출액)', '미지급금의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유동성장기부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타금융부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유상감자'): '',
#    ('(재무활동으로인한현금유출액)', '자기주식의취득'): '18,118',
#    ('(재무활동으로인한현금유출액)', '자본구성항목의감소'): '85',
#    ('(재무활동으로인한현금유출액)', '기타재무활동으로인한현금유출액'): '',
#    ('기타재무활동으로인한현금흐름', '기타재무활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-108,887',
#    ('기타재무활동으로인한현금흐름', '이자수입'): '',
#    ('기타재무활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타재무활동으로인한현금흐름', '배당금수입'): '',
#    ('기타재무활동으로인한현금흐름', '배당금지급(-)'): '-108,887',
#    ('기타재무활동으로인한현금흐름', '법인세환입'): '',
#    ('기타재무활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타재무활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '영업투자재무활동기타현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '연결범위변동으로인한현금의증가'): '',
#    ('기타재무활동으로인한현금흐름', '환율변동효과'): '48,210',
#    ('기타재무활동으로인한현금흐름', '현금및현금성자산의증가'): '-153,753',
#    ('기타재무활동으로인한현금흐름', '기초현금및현금성자산'): '690,809',
#    ('기타재무활동으로인한현금흐름', '기말현금및현금성자산'): '537,056'},
#   {('영업활동으로인한현금흐름', ''): '565,155',
#    ('당기순손익', ''): '255,651',
#    ('법인세비용차감전계속사업이익', ''): '',
#    ('현금유출이없는비용등가산', '현금유출이없는비용등가산계산에 참여한 계정 펼치기'): '440,320',
#    ('현금유출이없는비용등가산', '퇴직급여'): '12,028',
#    ('현금유출이없는비용등가산', '종업원급여'): '',
#    ('현금유출이없는비용등가산', '주식보상비'): '',
#    ('현금유출이없는비용등가산', '대손상각비'): '432',
#    ('현금유출이없는비용등가산', '감가상각비'): '322,489',
#    ('현금유출이없는비용등가산', '무형자산상각비'): '24,457',
#    ('현금유출이없는비용등가산', '계약부채전입액'): '',
#    ('현금유출이없는비용등가산', '반품(환불)부채전입액'): '',
#    ('현금유출이없는비용등가산', '배출부채전입액'): '',
#    ('현금유출이없는비용등가산', '충당부채전입액'): '',
#    ('현금유출이없는비용등가산', '외환손실'): '',
#    ('현금유출이없는비용등가산', '기타의대손상각비'): '',
#    ('현금유출이없는비용등가산', '금융원가'): '20,968',
#    ('현금유출이없는비용등가산', '이자비용'): '',
#    ('현금유출이없는비용등가산', '배당금지급'): '',
#    ('현금유출이없는비용등가산', '매출채권처분손실'): '',
#    ('현금유출이없는비용등가산', '당기손익-공정가치측정\xa0금융자산관련손실'): '',
#    ('현금유출이없는비용등가산', '금융자산처분손실'): '',
#    ('현금유출이없는비용등가산', '금융자산평가손실'): '',
#    ('현금유출이없는비용등가산', '금융자산손상차손'): '',
#    ('현금유출이없는비용등가산', '파생상품손실'): '',
#    ('현금유출이없는비용등가산', '금융부채관련손실'): '',
#    ('현금유출이없는비용등가산', '사채상환손실'): '',
#    ('현금유출이없는비용등가산', '재고자산감모손실'): '',
#    ('현금유출이없는비용등가산', '재고자산폐기(처분)손실'): '',
#    ('현금유출이없는비용등가산', '자산처분(폐기)손실'): '392',
#    ('현금유출이없는비용등가산', '투자자산평가손실'): '',
#    ('현금유출이없는비용등가산', '자산재평가손실'): '',
#    ('현금유출이없는비용등가산', '자산손상차손'): '29,341',
#    ('현금유출이없는비용등가산', '지분법관련손실'): '',
#    ('현금유출이없는비용등가산', '종속기업관련손실'): '',
#    ('현금유출이없는비용등가산', '관계기업관련손익'): '',
#    ('현금유출이없는비용등가산', '법인세비용'): '28,882',
#    ('현금유출이없는비용등가산', '기타비용'): '1,330',
#    ('(현금유입이없는수익등차감)', '(현금유입이없는수익등차감)계산에 참여한 계정 펼치기'): '61,101',
#    ('(현금유입이없는수익등차감)', '외환이익'): '',
#    ('(현금유입이없는수익등차감)', '대손충당금환입액'): '',
#    ('(현금유입이없는수익등차감)', '금융수익'): '53,728',
#    ('(현금유입이없는수익등차감)', '이자수익'): '',
#    ('(현금유입이없는수익등차감)', '배당금수익'): '936',
#    ('(현금유입이없는수익등차감)', '매출채권처분이익'): '',
#    ('(현금유입이없는수익등차감)', '당기손익-공정가치측정\xa0금융자산관련이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산처분이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '금융자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '파생상품이익'): '',
#    ('(현금유입이없는수익등차감)', '금융부채관련이익'): '',
#    ('(현금유입이없는수익등차감)', '사채상환이익'): '',
#    ('(현금유입이없는수익등차감)', '퇴직급여충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '계약부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '반품(환불)부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '배출부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '충당부채환입액'): '',
#    ('(현금유입이없는수익등차감)', '주식보상비환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산감모손실환입'): '',
#    ('(현금유입이없는수익등차감)', '재고자산폐기(처분)이익'): '',
#    ('(현금유입이없는수익등차감)', '자산처분(폐기)이익'): '854',
#    ('(현금유입이없는수익등차감)', '투자자산평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산재평가이익'): '',
#    ('(현금유입이없는수익등차감)', '자산손상차손환입'): '',
#    ('(현금유입이없는수익등차감)', '지분법관련이익'): '5,584',
#    ('(현금유입이없는수익등차감)', '종속회사관련이익'): '',
#    ('(현금유입이없는수익등차감)', '관계기업관련손익'): '',
#    ('(현금유입이없는수익등차감)', '법인세수익'): '',
#    ('(현금유입이없는수익등차감)', '기타수익'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)',
#     '영업활동으로인한자산부채변동(운전자본변동)계산에 참여한 계정 펼치기'): '-54,665',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '자산의감소(증가)'): '-65,037',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '부채의증가(감소)'): '-11,576',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '정부보조금등의변동'): '',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '기타운전자본의변동'): '21,948',
#    ('영업활동으로인한자산부채변동(운전자본변동)', '*영업에서창출된현금흐름'): '580,204',
#    ('기타영업활동으로인한현금흐름', '기타영업활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-15,049',
#    ('기타영업활동으로인한현금흐름', '이자수입'): '35,803',
#    ('기타영업활동으로인한현금흐름', '이자지급(-)'): '-3,441',
#    ('기타영업활동으로인한현금흐름', '배당금수입'): '2,239',
#    ('기타영업활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타영업활동으로인한현금흐름', '법인세환입'): '',
#    ('기타영업활동으로인한현금흐름', '법인세납부(-)'): '-49,651',
#    ('기타영업활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타영업활동으로인한현금흐름', '투자활동으로인한현금흐름'): '-375,212',
#    ('투자활동으로인한현금유입액', '투자활동으로인한현금유입액계산에 참여한 계정 펼치기'): '81,041',
#    ('투자활동으로인한현금유입액', '유동금융자산의감소'): '72,175',
#    ('투자활동으로인한현금유입액', '장기금융상품의감소'): '6,987',
#    ('투자활동으로인한현금유입액', '매도가능금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '만기보유금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '장기대여금의감소'): '',
#    ('투자활동으로인한현금유입액', '파생상품의변동'): '',
#    ('투자활동으로인한현금유입액', '기타비유동금융자산의감소'): '',
#    ('투자활동으로인한현금유입액', '관계기업등지분관련투자자산의감소'): '41',
#    ('투자활동으로인한현금유입액', '유형자산의감소'): '1,702',
#    ('투자활동으로인한현금유입액', '무형자산의감소'): '136',
#    ('투자활동으로인한현금유입액', '생물자산의감소'): '',
#    ('투자활동으로인한현금유입액', '투자부동산의감소'): '',
#    ('투자활동으로인한현금유입액', '기타투자활동으로인한현금유입액'): '',
#    ('(투자활동으로인한현금유출액)', '(투자활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '456,253',
#    ('(투자활동으로인한현금유출액)', '유동금융자산의증가'): '2,369',
#    ('(투자활동으로인한현금유출액)', '장기금융상품의증가'): '47,732',
#    ('(투자활동으로인한현금유출액)', '매도가능금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '만기보유금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '장기대여금의증가'): '',
#    ('(투자활동으로인한현금유출액)', '파생상품의변동'): '',
#    ('(투자활동으로인한현금유출액)', '기타비유동금융자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '관계기업등지분관련투자자산의증가'): '3,251',
#    ('(투자활동으로인한현금유출액)', '유형자산의증가'): '359,729',
#    ('(투자활동으로인한현금유출액)', '무형자산의증가'): '34,208',
#    ('(투자활동으로인한현금유출액)', '생물자산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '투자부동산의증가'): '',
#    ('(투자활동으로인한현금유출액)', '기타투자활동으로인한현금유출액'): '8,963',
#    ('기타투자활동으로인한현금흐름', '기타투자활동으로인한현금흐름계산에 참여한 계정 펼치기'): '',
#    ('기타투자활동으로인한현금흐름', '이자수입'): '',
#    ('기타투자활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '배당금수입'): '',
#    ('기타투자활동으로인한현금흐름', '배당금지급(-)'): '',
#    ('기타투자활동으로인한현금흐름', '법인세환입'): '',
#    ('기타투자활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타투자활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타투자활동으로인한현금흐름', '재무활동으로인한현금흐름'): '-189,361',
#    ('재무활동으로인한현금유입액', '재무활동으로인한현금유입액계산에 참여한 계정 펼치기'): '20,037',
#    ('재무활동으로인한현금유입액', '사채의증가'): '',
#    ('재무활동으로인한현금유입액', '차입금의증가'): '20,037',
#    ('재무활동으로인한현금유입액', '미지급금의증가'): '',
#    ('재무활동으로인한현금유입액', '유동성장기부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타금융부채의증가'): '',
#    ('재무활동으로인한현금유입액', '기타부채의증가'): '',
#    ('재무활동으로인한현금유입액', '유상증자'): '',
#    ('재무활동으로인한현금유입액', '자기주식의처분'): '',
#    ('재무활동으로인한현금유입액', '주식매입선택권의행사'): '',
#    ('재무활동으로인한현금유입액', '자본구성항목의증가'): '',
#    ('재무활동으로인한현금유입액', '기타재무활동으로인한현금유입액'): '',
#    ('(재무활동으로인한현금유출액)', '(재무활동으로인한현금유출액)계산에 참여한 계정 펼치기'): '134,961',
#    ('(재무활동으로인한현금유출액)', '사채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '차입금의감소'): '53,444',
#    ('(재무활동으로인한현금유출액)', '미지급금의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유동성장기부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타금융부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '기타부채의감소'): '',
#    ('(재무활동으로인한현금유출액)', '유상감자'): '',
#    ('(재무활동으로인한현금유출액)', '자기주식의취득'): '81,493',
#    ('(재무활동으로인한현금유출액)', '자본구성항목의감소'): '24',
#    ('(재무활동으로인한현금유출액)', '기타재무활동으로인한현금유출액'): '',
#    ('기타재무활동으로인한현금흐름', '기타재무활동으로인한현금흐름계산에 참여한 계정 펼치기'): '-74,438',
#    ('기타재무활동으로인한현금흐름', '이자수입'): '',
#    ('기타재무활동으로인한현금흐름', '이자지급(-)'): '',
#    ('기타재무활동으로인한현금흐름', '배당금수입'): '',
#    ('기타재무활동으로인한현금흐름', '배당금지급(-)'): '-74,438',
#    ('기타재무활동으로인한현금흐름', '법인세환입'): '',
#    ('기타재무활동으로인한현금흐름', '법인세납부(-)'): '',
#    ('기타재무활동으로인한현금흐름', '중단영업관련현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '영업투자재무활동기타현금흐름'): '',
#    ('기타재무활동으로인한현금흐름', '연결범위변동으로인한현금의증가'): '',
#    ('기타재무활동으로인한현금흐름', '환율변동효과'): '-3,643',
#    ('기타재무활동으로인한현금흐름', '현금및현금성자산의증가'): '-3,061',
#    ('기타재무활동으로인한현금흐름', '기초현금및현금성자산'): '537,056',
#    ('기타재무활동으로인한현금흐름', '기말현금및현금성자산'): '533,995'}]}

# %% [markdown]
# ## Snapshot | 기업정보 | Company Guide
